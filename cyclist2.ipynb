# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os  # Import the os module

# Define the path to the datasets
folder_path = r"C:\Users\ADMIN\Desktop\Cyclist_data\Excel_files"

all_files = os.listdir(folder_path)  # Corrected function name to listdir

data_frames = []

for filename in all_files:
    file_path = os.path.join(folder_path, filename)  # Create the full path for each file
    df = pd.read_csv(file_path)  # Read each CSV file
    data_frames.append(df)  # Add the DataFrame to the list

all_data = pd.concat(data_frames, ignore_index=True)  # Concatenate all DataFrames

# %%
for col in ['rideable_type', 'rideable_type' , 'started_at' , 'ended_at' ,'start_station_name', 'start_station_id', 
            'end_station_name', 'end_station_id', 'member_casual']:
    all_data[col] = all_data[col].astype('category')

print(all_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24828293 entries, 0 to 24828292
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       category
#  2   started_at          category
#  3   ended_at            category
#  4   start_station_name  category
#  5   start_station_id    category
#  6   end_station_name    category
#  7   end_station_id      category
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       category
# dtypes: category(8), float64(4), object(1)
# memory usage: 2.7+ GB
# None

# %%
print(all_data)
# Out:
#                    ride_id     rideable_type               started_at  \
# 0         A847FADBBC638E45       docked_bike      2020-04-26 17:45:14
# 1         5405B80E996FF60D       docked_bike      2020-04-17 17:08:54
# 2         5DD24A79A4E006F4       docked_bike      2020-04-01 17:54:13
# 3         2A59BBDF5CDBA725       docked_bike      2020-04-07 12:50:19
# 4         27AD306C119C6158       docked_bike      2020-04-18 10:22:59
# ...                    ...               ...                      ...
# 24828288  97CC940225245B6C  electric_scooter  2024-09-26 12:09:15.215
# 24828289  4F8F2383056480E0     electric_bike  2024-09-10 18:10:44.046
# 24828290  6A60FA5CF71D36E6     electric_bike  2024-09-14 10:52:22.777
# 24828291  F257ABC8B92ED5E5     electric_bike  2024-09-30 10:52:18.714
# 24828292  781862ED31812AE7     electric_bike  2024-09-20 22:49:21.914
#
#                          ended_at             start_station_name  \
# 0             2020-04-26 18:12:03                   Eckhart Park
# 1             2020-04-17 17:17:03      Drake Ave & Fullerton Ave
# 2             2020-04-01 18:08:36           McClurg Ct & Erie St
# 3             2020-04-07 13:02:31   California Ave & Division St
# 4             2020-04-18 11:15:54           Rush St & Hubbard St
# ...                           ...                            ...
# 24828288  2024-09-26 12:18:48.191  Franklin St & Adams St (Temp)
# 24828289  2024-09-10 18:21:54.463        Streeter Dr & Grand Ave
# 24828290  2024-09-14 11:03:36.081      Halsted St & Clybourn Ave
# 24828291  2024-09-30 11:31:46.032        Streeter Dr & Grand Ave
# 24828292  2024-09-20 23:37:15.731      Halsted St & Clybourn Ave
#
#          start_station_id             end_station_name end_station_id  \
# 0                      86  Lincoln Ave & Diversey Pkwy          152.0
# 1                     503              Kosciuszko Park          499.0
# 2                     142   Indiana Ave & Roosevelt Rd          255.0
# 3                     216       Wood St & Augusta Blvd          657.0
# 4                     125   Sheridan Rd & Lawrence Ave          323.0
# ...                   ...                          ...            ...
# 24828288     TA1309000008                          NaN            NaN
# 24828289            13022                          NaN            NaN
# 24828290              331                          NaN            NaN
# 24828291            13022                          NaN            NaN
# 24828292              331                          NaN            NaN
#
#           start_lat  start_lng  end_lat  end_lng member_casual
# 0         41.896400 -87.661000  41.9322 -87.6586        member
# 1         41.924400 -87.715400  41.9306 -87.7238        member
# 2         41.894500 -87.617900  41.8679 -87.6230        member
# 3         41.903000 -87.697500  41.8992 -87.6722        member
# 4         41.890200 -87.626200  41.9695 -87.6547        casual
# ...             ...        ...      ...      ...           ...
# 24828288  41.879339 -87.635700  41.9000 -87.6400        member
# 24828289  41.892278 -87.612043  41.8600 -87.6100        member
# 24828290  41.909701 -87.648408  41.9000 -87.6300        member
# 24828291  41.892278 -87.612043  41.8800 -87.6200        member
# 24828292  41.909668 -87.648128  41.9100 -87.6300        member
#
# [24828293 rows x 13 columns]

# %%
display(all_data)
# Out:
#                    ride_id     rideable_type               started_at  \
# 0         A847FADBBC638E45       docked_bike      2020-04-26 17:45:14
# 1         5405B80E996FF60D       docked_bike      2020-04-17 17:08:54
# 2         5DD24A79A4E006F4       docked_bike      2020-04-01 17:54:13
# 3         2A59BBDF5CDBA725       docked_bike      2020-04-07 12:50:19
# 4         27AD306C119C6158       docked_bike      2020-04-18 10:22:59
# ...                    ...               ...                      ...
# 24828288  97CC940225245B6C  electric_scooter  2024-09-26 12:09:15.215
# 24828289  4F8F2383056480E0     electric_bike  2024-09-10 18:10:44.046
# 24828290  6A60FA5CF71D36E6     electric_bike  2024-09-14 10:52:22.777
# 24828291  F257ABC8B92ED5E5     electric_bike  2024-09-30 10:52:18.714
# 24828292  781862ED31812AE7     electric_bike  2024-09-20 22:49:21.914
#
#                          ended_at             start_station_name  \
# 0             2020-04-26 18:12:03                   Eckhart Park
# 1             2020-04-17 17:17:03      Drake Ave & Fullerton Ave
# 2             2020-04-01 18:08:36           McClurg Ct & Erie St
# 3             2020-04-07 13:02:31   California Ave & Division St
# 4             2020-04-18 11:15:54           Rush St & Hubbard St
# ...                           ...                            ...
# 24828288  2024-09-26 12:18:48.191  Franklin St & Adams St (Temp)
# 24828289  2024-09-10 18:21:54.463        Streeter Dr & Grand Ave
# 24828290  2024-09-14 11:03:36.081      Halsted St & Clybourn Ave
# 24828291  2024-09-30 11:31:46.032        Streeter Dr & Grand Ave
# 24828292  2024-09-20 23:37:15.731      Halsted St & Clybourn Ave
#
#          start_station_id             end_station_name end_station_id  \
# 0                      86  Lincoln Ave & Diversey Pkwy          152.0
# 1                     503              Kosciuszko Park          499.0
# 2                     142   Indiana Ave & Roosevelt Rd          255.0
# 3                     216       Wood St & Augusta Blvd          657.0
# 4                     125   Sheridan Rd & Lawrence Ave          323.0
# ...                   ...                          ...            ...
# 24828288     TA1309000008                          NaN            NaN
# 24828289            13022                          NaN            NaN
# 24828290              331                          NaN            NaN
# 24828291            13022                          NaN            NaN
# 24828292              331                          NaN            NaN
#
#           start_lat  start_lng  end_lat  end_lng member_casual
# 0         41.896400 -87.661000  41.9322 -87.6586        member
# 1         41.924400 -87.715400  41.9306 -87.7238        member
# 2         41.894500 -87.617900  41.8679 -87.6230        member
# 3         41.903000 -87.697500  41.8992 -87.6722        member
# 4         41.890200 -87.626200  41.9695 -87.6547        casual
# ...             ...        ...      ...      ...           ...
# 24828288  41.879339 -87.635700  41.9000 -87.6400        member
# 24828289  41.892278 -87.612043  41.8600 -87.6100        member
# 24828290  41.909701 -87.648408  41.9000 -87.6300        member
# 24828291  41.892278 -87.612043  41.8800 -87.6200        member
# 24828292  41.909668 -87.648128  41.9100 -87.6300        member
#
# [24828293 rows x 13 columns]

# %%
# Check for missing values
missing_data = all_data.isnull().sum()
print(missing_data)

# let us how many rows are affected by missing data in the started_at, ended_at, start_station_name, start_station_id
columns_of_interest = ['started_at', 'ended_at', 'start_station_name', 'start_station_id', 'end_station_name', 'end_station_id']
missing_counts = df[columns_of_interest].isnull().sum()
rows_with_missing_data = df[columns_of_interest].isnull().sum(axis=1).sum()
print("\n\n")
print(f"Missing values in each column:\n{missing_counts}")
print(f"\nTotal rows with missing data in any of the specified columns: {rows_with_missing_data}")
print("\n\n")


# let us analyze the pattern of missing data

# Check for missing data by year
df['started_at'] = pd.to_datetime(df['started_at'], errors='coerce')
df['year'] = df['started_at'].dt.year
missing_by_year = df.groupby('year')[['start_station_name', 'start_station_id', 'end_station_name', 'end_station_id']].apply(lambda x: x.isnull().sum()).reset_index()
print(missing_by_year)
print("\n\n")

# Check missing data by ride type (member_casual)
missing_by_ride_type = df.groupby('member_casual')[['start_station_name', 'start_station_id', 'end_station_name', 'end_station_id']].apply(lambda x: x.isnull().sum())
print(missing_by_ride_type)
print("\n\n")

# Check missing data by start and end latitude and longitude
missing_by_location = df[['start_lat', 'start_lng', 'end_lat', 'end_lng']].isnull().sum()
print(missing_by_location)
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name    3375655
# start_station_id      3376410
# end_station_name      3578710
# end_station_id        3579312
# start_lat                   0
# start_lng                   0
# end_lat                 28133
# end_lng                 28133
# member_casual               0
# dtype: int64
#
#
#
# Missing values in each column:
# started_at                 0
# ended_at                   0
# start_station_name    189150
# start_station_id      189150
# end_station_name      192950
# end_station_id        192950
# dtype: int64
#
# Total rows with missing data in any of the specified columns: 764200
#
#
#
#    year  start_station_name  start_station_id  end_station_name  \
# 0  2024              189150            189150            192950
#
#    end_station_id
# 0          192950
#
#
#
#                start_station_name  start_station_id  end_station_name  \
# member_casual
# casual                      87812             87812             96291
# member                     101338            101338             96659
#
#                end_station_id
# member_casual
# casual                  96291
# member                  96659
#
#
#
# start_lat      0
# start_lng      0
# end_lat      753
# end_lng      753
# dtype: int64

# %%
# Convert columns to category dtype if not already
for col in ['start_station_name', 'start_station_id', 'end_station_name', 'end_station_id']:
    if all_data[col].dtype != 'category':  # Check if the column is not already category
        all_data[col] = all_data[col].astype('category')  # Convert to category dtype
    
    # Check if 'Unknown' is already a category, if not, add it
    if 'Unknown' not in all_data[col].cat.categories:
        all_data[col] = all_data[col].cat.add_categories('Unknown')

    # Replace missing values with 'Unknown'
    all_data[col] = all_data[col].fillna('Unknown')

# For the latitude and longitude columns (if they are still float), you can fill them with a placeholder string "Unknown"
# First, convert them to category and add "Unknown" as a category
for col in ['start_lat', 'start_lng', 'end_lat', 'end_lng']:
    all_data[col] = all_data[col].astype('category')
    if 'Unknown' not in all_data[col].cat.categories:
        all_data[col] = all_data[col].cat.add_categories('Unknown')  # Add 'Unknown' as a valid category
    all_data[col] = all_data[col].fillna('Unknown')  # Replace missing values with 'Unknown'

# Verify the changes
print(all_data.isnull().sum())  # Check if there are any remaining missing values
print(all_data['start_station_name'].unique())  # Check unique values for one of the columns
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64
# ['Eckhart Park', 'Drake Ave & Fullerton Ave', 'McClurg Ct & Erie St', 'California Ave & Division St', 'Rush St & Hubbard St', ..., 'Pulaski Rd & 60th Pl', 'Oriole Ave & Irving Park Rd', 'Princeton Ave & 95th St', 'Public Rack - Orville T Bright School', 'SCOOTERS CLASSIC - 2132 W Hubbard ST']
# Length: 2254
# Categories (2254, object): ['10101 S Stony Island Ave', '111th St - Morgan Park Metra', '2112 W Peterson Ave', '21st St & Pulaski Rd', ..., 'Yates Blvd & Exchange Ave', 'Zapata Academy', 'hubbard_test_lws', 'Unknown']

# %%
# EDA

#General summary statistics
summary_stats = all_data.describe(include = "all")
print(summary_stats)
display(summary_stats)
# Out:
#                  ride_id rideable_type           started_at  \
# count           24828293      24828293             24828293
# unique          24827873             4             21457162
# top     D179C51BB3994B59  classic_bike  2020-07-12 13:16:59
# freq                   2      10855243                   12
#
#                    ended_at start_station_name start_station_id  \
# count              24828293           24828293         24828293
# unique             21466131               2254             2462
# top     2022-08-22 12:47:49            Unknown          Unknown
# freq                     20            3375655          3376410
#
#        end_station_name end_station_id    start_lat    start_lng      end_lat  \
# count          24828293       24828293  24828293.00  24828293.00  24828293.00
# unique             2268           2469   1136904.00   1065403.00    506200.00
# top             Unknown        Unknown        41.89       -87.65        41.89
# freq            3578710        3579312    350469.00    503153.00    373450.00
#
#             end_lng member_casual
# count   24828293.00      24828293
# unique    460583.00             2
# top          -87.65        member
# freq      522988.00      14796224
#                  ride_id rideable_type           started_at  \
# count           24828293      24828293             24828293
# unique          24827873             4             21457162
# top     D179C51BB3994B59  classic_bike  2020-07-12 13:16:59
# freq                   2      10855243                   12
#
#                    ended_at start_station_name start_station_id  \
# count              24828293           24828293         24828293
# unique             21466131               2254             2462
# top     2022-08-22 12:47:49            Unknown          Unknown
# freq                     20            3375655          3376410
#
#        end_station_name end_station_id    start_lat    start_lng      end_lat  \
# count          24828293       24828293  24828293.00  24828293.00  24828293.00
# unique             2268           2469   1136904.00   1065403.00    506200.00
# top             Unknown        Unknown        41.89       -87.65        41.89
# freq            3578710        3579312    350469.00    503153.00    373450.00
#
#             end_lng member_casual
# count   24828293.00      24828293
# unique    460583.00             2
# top          -87.65        member
# freq      522988.00      14796224

# %%
# Count the number of rides by each member type (Casual vs Member)
member_ride_count = all_data['member_casual'].value_counts()
print(member_ride_count)


member_ride_count.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Total Rides by Member Type')
plt.xlabel('Member Type')
plt.ylabel('Number of Rides')
plt.xticks(rotation=0)
plt.show()
# Out:
# member_casual
# member    14796224
# casual    10032069
# Name: count, dtype: int64

# %%
# Count the number of rides by rideable type and member type
rideable_type_count = all_data.groupby(['member_casual', 'rideable_type']).size().unstack().fillna(0)
print(rideable_type_count)

# Visualize the preferred rideable types by member type
rideable_type_count.plot(kind='bar', stacked=True, color=['lightblue', 'lightgreen', 'lightcoral'])
plt.title('Preferred Rideable Types by Member Type')
plt.xlabel('Member Type')
plt.ylabel('Number of Rides')
plt.xticks(rotation=0)
plt.legend(title='Rideable Type')
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15000\307308887.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rideable_type_count = all_data.groupby(['member_casual', 'rideable_type']).size().unstack().fillna(0)
# rideable_type  classic_bike  docked_bike  electric_bike  electric_scooter
# member_casual
# casual              3870941      1665653        4410260             85215
# member              6984302      1441886        6310914             59122

# %%
#  Ride Duration Analysis
#  Average Ride Duration by Member Type
# Convert 'started_at' and 'ended_at' to datetime if not already done
df['started_at'] = pd.to_datetime(df['started_at'], errors='coerce')
df['ended_at'] = pd.to_datetime(df['ended_at'], errors='coerce')

# Calculate the ride duration in minutes
df['ride_duration'] = (df['ended_at'] - df['started_at']).dt.total_seconds() / 60

# Group by member type and calculate the average ride duration
avg_ride_duration = df.groupby('member_casual')['ride_duration'].mean()

print(avg_ride_duration)

# Set up the plot
plt.figure(figsize=(10, 6))

# Plot the distribution of ride durations by member type
sns.histplot(df[df['member_casual'] == 'casual']['ride_duration'], color='blue', label='Casual', kde=True, bins=50)
sns.histplot(df[df['member_casual'] == 'member']['ride_duration'], color='green', label='Member', kde=True, bins=50)

# Customize the plot
plt.title('Distribution of Ride Durations by Member Type')
plt.xlabel('Ride Duration (minutes)')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()
# Out:
# member_casual
# casual    21.631833
# member    12.212421
# Name: ride_duration, dtype: float64

# %%
# Ensure 'start_station_name' and 'end_station_name' are strings before concatenating
all_data['start_station_name'] = all_data['start_station_name'].astype(str)
all_data['end_station_name'] = all_data['end_station_name'].astype(str)

# Create a new column 'route' by combining 'start_station_name' and 'end_station_name'
all_data['route'] = all_data['start_station_name'] + " to " + all_data['end_station_name']

# Calculate the count of each route by member type
route_counts = all_data.groupby(['member_casual', 'route']).size().unstack(fill_value=0)

# Find the top 10 routes for each member type
top_routes_casual = all_data[all_data['member_casual'] == 'casual']['route'].value_counts().head(10)
top_routes_member = all_data[all_data['member_casual'] == 'member']['route'].value_counts().head(10)

print("Top 10 Routes for Casual Riders:\n", top_routes_casual)
print("\nTop 10 Routes for Members:\n", top_routes_member)

# Visualize the top routes for casual riders
plt.figure(figsize=(10, 6))
top_routes_casual.plot(kind='bar', color='skyblue')
plt.title('Top 10 Routes for Casual Riders')
plt.xlabel('Route')
plt.ylabel('Number of Rides')
plt.xticks(rotation=45, ha='right')
plt.show()

# Visualize the top routes for members
plt.figure(figsize=(10, 6))
top_routes_member.plot(kind='bar', color='lightgreen')
plt.title('Top 10 Routes for Annual Members')
plt.xlabel('Route')
plt.ylabel('Number of Rides')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15000\1853983792.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   route_counts = all_data.groupby(['member_casual', 'route']).size().unstack(fill_value=0)
# Top 10 Routes for Casual Riders:
#  route
# Unknown to Unknown                                                        802455
# Streeter Dr & Grand Ave to Streeter Dr & Grand Ave                         44415
# DuSable Lake Shore Dr & Monroe St to DuSable Lake Shore Dr & Monroe St     22716
# Michigan Ave & Oak St to Michigan Ave & Oak St                             22295
# Millennium Park to Millennium Park                                         21108
# DuSable Lake Shore Dr & Monroe St to Streeter Dr & Grand Ave               16819
# Buckingham Fountain to Buckingham Fountain                                 11922
# Theater on the Lake to Theater on the Lake                                 11860
# Indiana Ave & Roosevelt Rd to Indiana Ave & Roosevelt Rd                   11392
# Dusable Harbor to Dusable Harbor                                           11316
# Name: count, dtype: int64
#
# Top 10 Routes for Members:
#  route
# Unknown to Unknown                                 959209
# Ellis Ave & 60th St to Ellis Ave & 55th St          17507
# Ellis Ave & 60th St to University Ave & 57th St     16991
# University Ave & 57th St to Ellis Ave & 60th St     16283
# Ellis Ave & 55th St to Ellis Ave & 60th St          16154
# State St & 33rd St to Calumet Ave & 33rd St         15283
# Calumet Ave & 33rd St to State St & 33rd St         15161
# Loomis St & Lexington St to Morgan St & Polk St     10529
# Morgan St & Polk St to Loomis St & Lexington St      9795
# MLK Jr Dr & 29th St to State St & 33rd St            8036
# Name: count, dtype: int64

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\admin\anaconda3\lib\site-packages (1.0.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.22 in c:\users\admin\anaconda3\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\admin\anaconda3\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\admin\anaconda3\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\admin\anaconda3\lib\site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\admin\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)

# %%
pip install geodatasets
# Out:
# Requirement already satisfied: geodatasets in c:\users\admin\anaconda3\lib\site-packages (2024.8.0)
# Requirement already satisfied: pooch in c:\users\admin\anaconda3\lib\site-packages (from geodatasets) (1.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\admin\anaconda3\lib\site-packages (from pooch->geodatasets) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from pooch->geodatasets) (23.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\admin\anaconda3\lib\site-packages (from pooch->geodatasets) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->geodatasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->geodatasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->geodatasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->geodatasets) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import geopandas as gpd
import geodatasets
import matplotlib.pyplot as plt

# Assuming `all_data` is your main DataFrame
casual_riders = all_data[all_data['member_casual'] == 'casual']
member_riders = all_data[all_data['member_casual'] == 'member']

# Create GeoDataFrames
casual_gdf = gpd.GeoDataFrame(casual_riders, geometry=gpd.points_from_xy(casual_riders['start_lng'], casual_riders['start_lat']))
member_gdf = gpd.GeoDataFrame(member_riders, geometry=gpd.points_from_xy(member_riders['start_lng'], member_riders['start_lat']))

# Load the world map with geopandas directly (as naturalearth_lowres)
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter the map for the United States
city_map = world[world.name == "United States of America"]

# Plot the map
fig, ax = plt.subplots(figsize=(10, 10))
city_map.plot(ax=ax, color='lightgray')
casual_gdf.plot(ax=ax, marker='o', color='blue', markersize=5, label='Casual Riders')
member_gdf.plot(ax=ax, marker='o', color='red', markersize=5, label='Member Riders')
plt.legend()
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 import matplotlib.pyplot as plt
#       6 # Assuming `all_data` is your main DataFrame
# ----> 7 casual_riders = all_data[all_data['member_casual'] == 'casual']
#       8 member_riders = all_data[all_data['member_casual'] == 'member']
#      10 # Create GeoDataFrames
#
# NameError: name 'all_data' is not defined

# %%
# Convert 'started_at' and 'ended_at' columns to datetime
all_data['started_at'] = pd.to_datetime(all_data['started_at'], errors='coerce')
all_data['ended_at'] = pd.to_datetime(all_data['ended_at'], errors='coerce')

#  Calculate the ride length (in minutes)
all_data['ride_length'] = (all_data['ended_at'] - all_data['started_at']).dt.total_seconds() / 60

# Convert ride length to HH:MM:SS format
all_data['ride_length_formatted'] = pd.to_datetime(all_data['ride_length'], unit='m').dt.strftime('%H:%M:%S')

#  Calculate the average ride duration by member type
avg_ride_duration = all_data.groupby('member_casual')['ride_length'].mean()
print("Average Ride Duration by Member Type:")
print(avg_ride_duration)

#  Calculate the average ride length by day of the week (1 = Sunday, 7 = Saturday)
all_data['day_of_week'] = all_data['started_at'].dt.dayofweek + 1  # 1 = Sunday, 7 = Saturday

avg_ride_duration_by_day = all_data.groupby('day_of_week')['ride_length'].mean()
print("\nAverage Ride Length by Day of the Week:")
print(avg_ride_duration_by_day)

#  Visualize the results

# Plot average ride duration by member type
plt.figure(figsize=(8, 6))
sns.barplot(x=avg_ride_duration.index, y=avg_ride_duration.values, palette='Blues')
plt.title('Average Ride Duration by Member Type')
plt.xlabel('Member Type')
plt.ylabel('Average Ride Duration (minutes)')
plt.show()

# Plot average ride length by day of the week
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_ride_duration_by_day.index, y=avg_ride_duration_by_day.values, palette='viridis')
plt.title('Average Ride Length by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Average Ride Length (minutes)')
plt.xticks(ticks=range(7), labels=['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'])
plt.show()
